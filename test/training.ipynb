# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('science.mplstyle')

# %%
df = pd.read_csv('../data/trained_model/training_log.csv')
df
# Out:
#     epoch  train_loss  val_loss        lr  time_s  grad_norm
# 0       1    0.006814  0.003660  0.000498    90.1     0.1154
# 1       2    0.003015  0.002435  0.000492    88.2     0.1197
# 2       3    0.002337  0.002121  0.000482    94.5     0.1158
# 3       4    0.002042  0.001761  0.000469    82.3     0.1114
# 4       5    0.001879  0.001711  0.000452    82.7     0.1058
# 5       6    0.001602  0.001560  0.000432    82.1     0.0925
# 6       7    0.001452  0.001432  0.000409    83.4     0.0872
# 7       8    0.001329  0.001297  0.000384    83.2     0.0843
# 8       9    0.001233  0.001271  0.000356    83.0     0.0801
# 9      10    0.001145  0.001145  0.000327    85.5     0.0765
# 10     11    0.001071  0.001075  0.000297    84.7     0.0740
# 11     12    0.001004  0.001084  0.000266    85.7     0.0703
# 12     13    0.000941  0.001024  0.000234    83.1     0.0675
# 13     14    0.000882  0.000928  0.000203    82.9     0.0635
# 14     15    0.000828  0.000827  0.000173    82.8     0.0616
# 15     16    0.000780  0.000806  0.000144    82.7     0.0583
# 16     17    0.000733  0.000767  0.000116    82.7     0.0541
# 17     18    0.000691  0.000729  0.000091    84.9     0.0504
# 18     19    0.000653  0.000680  0.000068    86.7     0.0463
# 19     20    0.000621  0.000635  0.000048    85.2     0.0437
# 20     21    0.000592  0.000612  0.000031    85.9     0.0397
# 21     22    0.000568  0.000593  0.000018    84.1     0.0361

# %%
fig = plt.figure(figsize=(10, 4))

plt.scatter(df.epoch, df.train_loss, color='black', label='Training Loss')
plt.scatter(df.epoch, df.val_loss, color='red', label='Validation Loss')

plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.yscale('log')
plt.legend()
